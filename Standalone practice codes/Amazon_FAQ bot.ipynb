# %%
responses = {"How to place an order with Amazon": "To begin ordering, you may visit the Amazon website. If you are using an Android phone, you may download and install the Amazon Shopping app", 
"Why am I unable to place an order": "There is a Payment decline. Please select here to know more about Payment issues.; The item you have selected is out of stock.; There is some technical or internet connectivity issue.; sometimes when Fulfiiled by Amazon and seller fulfilled items are clubbed together, the order processing takes time.",
"How to change quantities of Orders in the cart": "Once you select the 'Add to Cart' button and add the item to your shopping cart, enter the desired quantity in the 'Quantity' dropdown option on the right side of the page.",
"Can I change or modify orders that are already placed": "You would not be able to change or modify the number of items once you have already placed an order. You can place another fresh order with the desired modifications. However, you can change your shipping preferences in Your Account at any time after placing your order as long as the order hasn't entered the shipping process yet.",
"How to place bulk orders": "You can bulk order new products from Amazon Business. To order, select the following link:https://www.amazon.in/ab/bulk-order/",
"How to update delivery instructions": "Tell us what you'd like us to do with your parcel if you're not at home to receive it.",
"How to change the payment method": "You can add or update your payment methods by selecting the payments options section in Your Account.",
"What is cash on delivery": "Cash on Delivery is one of the payment methods for making purchases on Amazon.in. When you select Cash on Delivery as your payment method, you don't have to make any advance payment. You pay for your order only when you receive it.",
"How to cancel orders": "You can cancel items or orders by visiting the Your Orders section in Your Account.",
"How to place Gift orders": "You can choose to gift-wrap any item from your shopping cart as long as it is fulfilled by Amazon.",
"What is Amazon Bazaar":"Amazon Bazaar is a new store on Amazon.in, offering a dedicated destination for fashion and home products at affordable prices. You can find items from clothing, accessories, and jewelry to handbags, shoes, traditional and western wear, and a wide array of home goods including kitchenware, towels, bed linens, and décor items."}

def get_bot_response(user_input):
    user_input = user_input.lower()
    for keyword,response in responses.items():
        if keyword in user_input:
            return response
    return "I'm sorry, I don't have an answer for that. Please try asking something else or check the Amazon help section for more information."
while True:
    user_input = input("You:")
    if user_input.lower() in ["exit", "quit", "stop"]:
        print("Bot: Goodbye! Have a nice day!")
        break

response = get_bot_response(user_input)
print(f"Bot: {response}")
